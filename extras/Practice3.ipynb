# %%
#list is a sequence of data points,[] indicate that elements inside form a list, not a diff type of sequence and use ' '

# %%
participants=['John', 'Adam', 'Jack']
print (participants[1])
# Out:
# Adam

# %%
#to get elements from end of a list
participants[-1]
# Out:
# 'Jack'

# %%
#to replace value in a list
participants[2] = "James"
participants
# Out:
# ['John', 'Adam', 'James']

# %%
#del deletes element in a list
participants=['John', 'Adam', 'James']
del participants[0];
participants
# Out:
# ['Adam', 'James']

# %%
# Object name.append() adds element in a list
# . is called dot operator and allows to invoke or call in a method
# extend adds element in a list. Elements must come in single quotes and []
# list elements are treated as string values
# append adds element in a list. Elements must come in double quotes and ()

# %%
participants=['John', 'Adam', 'James']
participants.append("Mike")
participants
# Out:
# ['John', 'Adam', 'James', 'Mike']

# %%
participants=['John', 'Adam', 'James', 'Mike']
participants.extend(['George', 'Catherine'])
participants
# Out:
# ['John', 'Adam', 'James', 'Mike', 'George', 'Catherine']

# %%
participants=['John', 'Adam', 'James', 'Mike', 'George', 'Catherine']
print('The first participant is ' + participants[0])
# Out:
# The first participant is John

# %%
len(participants)
# Out:
# 6

# %%
#Slicing gets a smaller list out of a bigger list. 
# XYZ[a, b, c, d, e]
#To slice b and d, XYZ[1, 4]
# 4 is used instead of 3 because the formula of 2nd position is 1 + the last pos we need
participants=['John', 'Adam', 'James', 'Mike', 'George', 'Catherine']
participants[1:3]
# Out:
# ['Adam', 'James']

# %%
participants=['John', 'Adam', 'James', 'Mike', 'George', 'Catherine'] 
participants[:2]
# Out:
# ['John', 'Adam']

# %%
participants[4:]
# Out:
# ['George', 'Catherine']

# %%
participants=['John', 'Adam', 'James', 'Mike', 'George', 'Catherine']
participants[-2:]
# Out:
# ['George', 'Catherine']

# %%
#to find postition in a list
participants.index("James")
# Out:
# 2

# %%
Newcomers=['Joshua', 'Brittany']
Newcomers
# Out:
# ['Joshua', 'Brittany']

# %%
Bigger_List=[participants, Newcomers]
Bigger_List
# Out:
# [['John', 'Adam', 'James', 'Mike', 'George', 'Catherine'],
#  ['Joshua', 'Brittany']]

# %%
#.sort() sorts list objects
participants.sort()
participants
# Out:
# ['Adam', 'Catherine', 'George', 'James', 'John', 'Mike']

# %%
participants.sort(reverse=True)
participants
# Out:
# ['Mike', 'John', 'James', 'George', 'Catherine', 'Adam']

# %%
#Tuples are a type data sequence that can't be changed. Elements come in a ()
#All list are by default tuples. They're placed in (), not []
x=(2, 5, 8)
x
# Out:
# (2, 5, 8)

# %%
x[0]
# Out:
# 2

# %%
y=50, 51, 52
list=[x,y]
list
# Out:
# [(2, 5, 8), (50, 51, 52)]

# %%
#Split method assigns a particular element as the method of divided each value to a var
(age, years_of_school)="30,17".split(',')
print (age)
print (years_of_school)
# Out:
# 30
# 17

# %%
#fs can provide tuples, which hold mult values, as return values
def square_info(x):
    A=x**2
    P=A*x
    print("Area and perimeter:")
    return A, P

square_info(3)
# Out:
# Area and perimeter:
# (9, 27)

# %%
#Dictionaries represent a way of storing data, each value is associated with a certain key
# Key and it's value form a key-value pair. Only {} are used. The value can be accesed using its' key
dict={'k1':"Cat", 'k2':"dog", 'k3':"mouse", 'k4':"fish"}
dict
# Out:
# {'k1': 'Cat', 'k2': 'dog', 'k3': 'mouse', 'k4': 'fish'}

# %%
dict['k1']
# Out:
# 'Cat'

# %%
#To add new value to dictionary, DicName['New key name']='new value'
dict['k5']='parrot'
dict
# Out:
# {'k1': 'Cat', 'k2': 'dog', 'k3': 'mouse', 'k4': 'fish', 'k5': 'parrot'}

# %%
#To replace a value
dict['k2']='squirrel'
dict
# Out:
# {'k1': 'Cat', 'k2': 'squirrel', 'k3': 'mouse', 'k4': 'fish', 'k5': 'parrot'}

# %%
dep_workers={'dep_1':['Peter'], 'dep_2':['Jen','Mike','Tom']}

# %%
dep_workers['dep_2']
# Out:
# ['Jen', 'Mike', 'Tom']

# %%
#Alt method to make a dic
Team={}
Team['Dive']='A'
Team['Foot']='B'
Team['Race']='C'
print (Team)
# Out:
# {'Dive': 'A', 'Foot': 'B', 'Race': 'C'}

# %%
print (Team['Dive'])
# Out:
# A

# %%
print (Team.get('Foot'))
# Out:
# B

# %%
print (Team.get('Shoot'))
# Out:
# None

# %%
Menu = {'meal_1':'Spaghetti', 'meal_2':'Fries', 'meal_3':'Cheeseburger', 'meal_4':'Lasagna', 'meal_5':'Soup'}
Dessert = ['Pancakes', 'Ice-cream', 'Tiramisu']
Menu['meal_6']=Dessert
print(Menu)
# Out:
# {'meal_1': 'Spaghetti', 'meal_2': 'Fries', 'meal_3': 'Cheeseburger', 'meal_4': 'Lasagna', 'meal_5': 'Soup', 'meal_6': ['Pancakes', 'Ice-cream', 'Tiramisu']}
