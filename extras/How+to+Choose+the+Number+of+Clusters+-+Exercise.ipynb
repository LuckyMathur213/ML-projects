# %% [markdown]
# # How to Choose the Number of Clusters

# %% [markdown]
# Using the same code as in the previous exercise, find the WCSS for clustering solutions with 1 to 10 clusters (you can try with more if you wish).
#
# Find the most suitable solutions, run them and compare the results.

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'Countries_exercise.csv'</i>.

# %%
data=pd.read_csv('Countries-exercise.csv')

# %% [markdown]
# Remove the duplicate index column from the dataset.

# %%
data
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %% [markdown]
# ## Plot the data

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %%
plt.scatter(data['Longitude'],data['Latitude'])
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.show()

# %% [markdown]
# ## Select the features

# %% [markdown]
# Make sure to select the appropriate features since we are no longer using the categorical variable for our clustering but rather <i>'Longitude'</i> and <i>'Laditude'</i>.

# %%
x=data.iloc[:,1:3]
x
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# ..          ...        ...
# 236 -172.164851 -13.753243
# 237   47.586762  15.909280
# 238   25.083901 -29.000341
# 239   27.774759 -13.458242
# 240   29.851441 -19.004204
#
# [241 rows x 2 columns]

# %% [markdown]
# ## Clustering

# %% [markdown]
# Use 4 clusters initially.

# %%
km=KMeans(4)

# %% [markdown]
# ### Clustering results

# %%
km.fit(x)
# Out:
# C:\Users\navee\Documents\pytho\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
clu=km.fit_predict(x)
clu
# Out:
# C:\Users\navee\Documents\pytho\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([2, 3, 3, 2, 3, 3, 3, 3, 2, 3, 0, 3, 1, 1, 2, 1, 3, 3, 3, 3, 3, 3,
#        1, 3, 3, 2, 2, 3, 2, 3, 2, 2, 2, 2, 2, 1, 1, 3, 3, 3, 2, 1, 3, 3,
#        3, 3, 0, 2, 3, 2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 2, 3, 2, 3, 2, 3, 3,
#        3, 3, 3, 3, 1, 2, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2,
#        1, 2, 1, 1, 2, 3, 2, 3, 1, 3, 1, 1, 1, 3, 3, 3, 3, 3, 3, 2, 3, 3,
#        1, 1, 3, 3, 1, 1, 2, 2, 1, 3, 3, 1, 3, 3, 3, 2, 3, 1, 3, 3, 3, 3,
#        1, 2, 3, 3, 3, 3, 1, 2, 1, 3, 3, 3, 1, 3, 1, 1, 3, 3, 2, 3, 3, 1,
#        3, 1, 3, 1, 3, 2, 0, 3, 3, 1, 1, 1, 3, 3, 2, 0, 2, 1, 1, 1, 3, 2,
#        1, 3, 2, 3, 0, 3, 3, 1, 3, 3, 3, 3, 3, 3, 1, 2, 3, 1, 3, 2, 3, 3,
#        3, 2, 3, 3, 2, 3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 1, 3, 3, 1, 0, 2, 3,
#        3, 1, 3, 3, 3, 2, 2, 3, 3, 2, 2, 2, 2, 1, 1, 0, 0, 3, 3, 3, 3])

# %%
d_w_cl=data.copy()
d_w_cl['Cluster']=clu
d_w_cl
# Out:
#              name   Longitude   Latitude  Cluster
# 0           Aruba  -69.982677  12.520880        2
# 1     Afghanistan   66.004734  33.835231        3
# 2          Angola   17.537368 -12.293361        3
# 3        Anguilla  -63.064989  18.223959        2
# 4         Albania   20.049834  41.142450        3
# ..            ...         ...        ...      ...
# 236         Samoa -172.164851 -13.753243        0
# 237         Yemen   47.586762  15.909280        3
# 238  South Africa   25.083901 -29.000341        3
# 239        Zambia   27.774759 -13.458242        3
# 240      Zimbabwe   29.851441 -19.004204        3
#
# [241 rows x 4 columns]

# %% [markdown]
# Plot the data once again but separate the data by the clusters we defined.

# %% [markdown]
# ## Plot the data

# %%
plt.scatter(d_w_cl['Longitude'],d_w_cl['Latitude'],c=d_w_cl['Cluster'],cmap='rainbow')
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.show()

# %% [markdown]
# ## Selecting the number of clusters

# %% [markdown]
# ### WCSS

# %% [markdown]
# Use the ingerated <i>sklearn</i> method <i> 'inertia_' </i>.

# %%
km.inertia_
# Out:
# 259422.69076316024

# %% [markdown]
# Write a loop that calculates and saves the WCSS for any number of clusters from 1 up to 10 (or more if you wish).

# %%
wcss=[]
for i in range(1,15):
    km=KMeans(i)
    km.fit(x)
    wcss_iter=km.inertia_
    wcss.append(wcss_iter)

# %%
wcss
# Out:
# [1413859.6798344273,
#  657012.0797586325,
#  325254.48120331316,
#  284150.3796162815,
#  218778.3966355183,
#  154603.1013281589,
#  128514.3990875891,
#  110711.43427884436,
#  85732.86460438173,
#  83716.05961551776,
#  70608.85235589977,
#  68310.72462226625,
#  61469.746377180345,
#  58252.57984954791]

# %% [markdown]
# ### The Elbow Method

# %%
clus_num=range(1,15)
plt.plot(clus_num,wcss)
plt.xticks(np.arange(1,15,step=1))
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')

# %% [markdown]
# Based on the Elbow Curve, plot several graphs with the appropriate amounts of clusters you believe would best fit the data.

# %% [markdown]
# Compare the scatter plots to determine which one to use in our further analysis.

# %% [markdown]
# <i>Hint: we already created the scatter plot for 4 clusters, so we only have to slightly alter our code.</i>

# %%
km=KMeans(11)
km.fit(x)
# Out:
# KMeans(n_clusters=11)

# %%
clu=km.fit_predict(x)
clu
# Out:
# array([ 3,  4,  5,  3,  0,  0,  0,  4,  8,  4,  2, 10,  6, 10,  3,  1,  0,
#         4,  5,  0,  7,  7,  9,  0,  4,  3,  3,  0,  3,  0,  3,  3,  8,  8,
#         3,  6,  9,  5,  5,  0,  8,  9,  7,  7,  5,  7,  2,  3,  5,  7,  3,
#         3,  3,  3,  4,  4,  0,  0,  5,  3,  0,  3,  7,  3,  4,  4,  0,  0,
#         5,  0,  1,  8,  0,  0,  6,  7,  0,  4,  0,  7,  7,  7,  7,  7,  0,
#         3,  0,  3,  6,  3,  9, 10,  3,  0,  3,  0,  6,  0,  9,  9,  5,  0,
#         4,  4,  0,  4,  0,  3,  0,  4,  6,  4,  4,  5,  4,  9,  3,  3,  9,
#         0,  4,  9,  4,  7,  0,  3,  0,  9,  5,  0,  0,  0,  9,  3,  7,  0,
#         0,  5,  9,  3,  1,  0,  7,  0,  9,  0,  9,  6,  5,  7,  3,  5,  5,
#         9,  5,  1,  7,  1,  7,  3,  2,  0,  0,  9,  1,  1,  4,  4,  3,  2,
#         3,  6,  6,  6,  0,  3,  9,  0,  8,  4,  2,  4,  0,  9,  5,  7,  4,
#         5,  5,  7,  9,  8,  7,  1,  7,  3,  0,  5,  5,  3,  0,  7,  3,  0,
#         0,  0,  5,  3,  5,  4,  3,  7,  7,  9,  4,  4,  6,  2,  3,  0,  4,
#         9,  5,  5,  0,  8,  3,  4,  0,  3,  3,  3,  3,  9,  1,  2,  2,  4,
#         5,  5,  5])

# %%
d_w_cl=data.copy()
d_w_cl['Cluster']=clu
d_w_cl
# Out:
#              name   Longitude   Latitude  Cluster
# 0           Aruba  -69.982677  12.520880        3
# 1     Afghanistan   66.004734  33.835231        4
# 2          Angola   17.537368 -12.293361        5
# 3        Anguilla  -63.064989  18.223959        3
# 4         Albania   20.049834  41.142450        0
# ..            ...         ...        ...      ...
# 236         Samoa -172.164851 -13.753243        2
# 237         Yemen   47.586762  15.909280        4
# 238  South Africa   25.083901 -29.000341        5
# 239        Zambia   27.774759 -13.458242        5
# 240      Zimbabwe   29.851441 -19.004204        5
#
# [241 rows x 4 columns]

# %%
plt.scatter(d_w_cl['Longitude'],d_w_cl['Latitude'],c=d_w_cl['Cluster'],cmap='rainbow')
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.show()
