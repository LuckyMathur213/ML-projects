# %% [markdown]
# # Clustering Categorical Data

# %% [markdown]
# You are given much more country data. Using the same methodology as the one in the lecture, group all the countries in 2 clusters.
#
# <b> Already done that? Okay! </b>
#
# There are other features: name and continent.
#
# Encode the continent one and use it in the clustering solution. Think about the difference with the previous exercise.

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'Categorical.csv'</i>.

# %%
data=pd.read_csv('Categorical.csv')
data
# Out:
#              name   Longitude   Latitude      continent
# 0           Aruba  -69.982677  12.520880  North America
# 1     Afghanistan   66.004734  33.835231           Asia
# 2          Angola   17.537368 -12.293361         Africa
# 3        Anguilla  -63.064989  18.223959  North America
# 4         Albania   20.049834  41.142450         Europe
# ..            ...         ...        ...            ...
# 236         Samoa -172.164851 -13.753243        Oceania
# 237         Yemen   47.586762  15.909280           Asia
# 238  South Africa   25.083901 -29.000341         Africa
# 239        Zambia   27.774759 -13.458242         Africa
# 240      Zimbabwe   29.851441 -19.004204         Africa
#
# [241 rows x 4 columns]

# %% [markdown]
# Remove the duplicate index column from the dataset.

# %%
data_mapped=data.copy()

# %% [markdown]
# ## Map the data

# %% [markdown]
# Use the <i>'continent'</i> category for this analysis.

# %%
data_mapped['continent']=data_mapped['continent'].map({'North America':0,'Europe':1,'Asia':2,'Africa':3,'South America':4, 'Oceania':5,'Seven seas (open ocean)':6, 'Antarctica':7})

# %% [markdown]
# ## Select the features

# %%
x = data_mapped.iloc[:,3:4]
x
# Out:
#      continent
# 0            0
# 1            2
# 2            3
# 3            0
# 4            1
# ..         ...
# 236          5
# 237          2
# 238          3
# 239          3
# 240          3
#
# [241 rows x 1 columns]

# %% [markdown]
# ## Clustering

# %% [markdown]
# Use 4 clusters initially.

# %%
km=KMeans(7)

# %% [markdown]
# ## Clustering results

# %%
km.fit(x)
# Out:
# C:\Users\navee\Documents\pytho\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=7)

# %%
clu=km.fit_predict(x)
clu
# Out:
# C:\Users\navee\Documents\pytho\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([4, 0, 3, 4, 2, 2, 2, 0, 5, 0, 1, 6, 1, 6, 4, 1, 2, 0, 3, 2, 3, 3,
#        0, 2, 0, 4, 4, 2, 4, 2, 4, 4, 5, 5, 4, 0, 0, 3, 3, 2, 5, 0, 3, 3,
#        3, 3, 1, 5, 3, 3, 4, 4, 4, 4, 0, 0, 2, 2, 3, 4, 2, 4, 3, 5, 3, 3,
#        2, 2, 3, 2, 1, 5, 2, 2, 1, 3, 2, 0, 2, 3, 3, 3, 3, 3, 2, 4, 4, 4,
#        1, 5, 0, 6, 4, 2, 4, 2, 0, 2, 0, 0, 6, 2, 0, 0, 2, 0, 2, 4, 2, 0,
#        0, 0, 0, 3, 0, 0, 1, 4, 0, 2, 0, 0, 0, 3, 3, 4, 2, 0, 3, 2, 2, 2,
#        0, 4, 3, 2, 2, 3, 6, 4, 1, 2, 3, 2, 0, 2, 0, 1, 3, 3, 4, 6, 3, 0,
#        3, 1, 3, 1, 3, 4, 1, 2, 2, 0, 1, 1, 0, 0, 4, 1, 5, 0, 1, 1, 2, 4,
#        0, 2, 5, 0, 1, 0, 2, 2, 3, 3, 0, 3, 3, 3, 0, 6, 6, 1, 3, 4, 2, 3,
#        3, 4, 2, 3, 5, 2, 2, 2, 3, 4, 6, 0, 4, 3, 3, 0, 0, 0, 0, 1, 4, 3,
#        0, 0, 3, 3, 2, 5, 4, 0, 2, 4, 5, 4, 4, 0, 1, 1, 1, 0, 3, 3, 3])

# %% [markdown]
# ## Plot the data

# %%
d_w_clu=data_mapped.copy()
d_w_clu['Cluster']=clu
d_w_clu
# Out:
#              name   Longitude   Latitude  continent  Cluster
# 0           Aruba  -69.982677  12.520880          0        4
# 1     Afghanistan   66.004734  33.835231          2        0
# 2          Angola   17.537368 -12.293361          3        3
# 3        Anguilla  -63.064989  18.223959          0        4
# 4         Albania   20.049834  41.142450          1        2
# ..            ...         ...        ...        ...      ...
# 236         Samoa -172.164851 -13.753243          5        1
# 237         Yemen   47.586762  15.909280          2        0
# 238  South Africa   25.083901 -29.000341          3        3
# 239        Zambia   27.774759 -13.458242          3        3
# 240      Zimbabwe   29.851441 -19.004204          3        3
#
# [241 rows x 5 columns]

# %%
plt.scatter(d_w_clu['Longitude'],d_w_clu['Latitude'],c=d_w_clu['Cluster'],cmap='rainbow')
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.show()

# %% [markdown]
# Since you already have all the code necessary, go back and play around with the .number of clusters. Try 3, 7 and 8 and see if the results match your expectations.

# %% [markdown]
# Simply go back to the beggining of the <b> Clustering </b> section and change <i> kmeans = KMeans(4) </i> to <i> kmeans = KMeans(3) </i>. Then run the remaining cells until the end.
