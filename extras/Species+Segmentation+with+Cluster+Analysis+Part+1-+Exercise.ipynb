# %% [markdown]
# # Species Segmentation with Cluster Analysis

# %% [markdown]
# The Iris flower dataset is one of the most popular ones for machine learning. You can read a lot about it online and have probably already heard of it: https://en.wikipedia.org/wiki/Iris_flower_data_set
#
# We didn't want to use it in the lectures, but believe that it would be very interesting for you to try it out (and maybe read about it on your own).
#
# There are 4 features: sepal length, sepal width, petal length, and petal width.
#
# Start by creating 2 clusters. Then standardize the data and try again. Does it make a difference?
#
# Use the Elbow rule to determine how many clusters are there.

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'iris_dataset.csv'</i>.

# %%
data=pd.read_csv('iris_dataset.csv')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Plot the data

# %% [markdown]
# For this exercise, try to cluster the iris flowers by the shape of their sepal.
#
# <i> Use the 'sepal_length' and 'sepal_width' variables.</i>

# %%
plt.scatter(data['sepal_length'],data['sepal_width'])
plt.ylabel('sepal_width')
plt.xlabel('sepal_length')
plt.show()

# %% [markdown]
# # Clustering (unscaled data)

# %% [markdown]
# Separate the original data into 2 clusters.

# %%
x=data.copy()
km=KMeans(2)
km.fit(x)
# Out:
# C:\Users\navee\Documents\pytho\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
clu=x.copy()
clu['Predicted_cluster']=km.fit_predict(x)
# Out:
# C:\Users\navee\Documents\pytho\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.scatter(data['sepal_length'],data['sepal_width'],c=clu['Predicted_cluster'],cmap='rainbow')
plt.ylabel('sepal_width')
plt.xlabel('sepal_length')
plt.show()

# %% [markdown]
# # Standardize the variables

# %% [markdown]
# Import and use the <i> method </i> function from sklearn to standardize the data.

# %%
from sklearn import preprocessing
x_scaled=preprocessing.scale(x)

# %% [markdown]
# # Clustering (scaled data)

# %%
km_s=KMeans(2)
km_s.fit(x_scaled)
# Out:
# C:\Users\navee\Documents\pytho\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
clu_s=x.copy()
clu_s['Standardized_pred_cluster']=km_s.fit_predict(x_scaled)
# Out:
# C:\Users\navee\Documents\pytho\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
clu_s
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  \
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
#      Standardized_pred_cluster
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            1
# ..                         ...
# 145                          0
# ...

# %%
plt.scatter(clu_s['sepal_length'],clu_s['sepal_width'],c=clu_s['Standardized_pred_cluster'],cmap='rainbow')
plt.ylabel('sepal_width')
plt.xlabel('sepal_length')
plt.show()

# %% [markdown]
# ## Take Advantage of the Elbow Method

# %% [markdown]
# ### WCSS

# %%
wcss=[]
for i in range(1,11):
    km=KMeans(i)
    km.fit(x_scaled)
    wcss.append(km.inertia_)

wcss
# Out:
# C:\Users\navee\Documents\pytho\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\navee\Documents\pytho\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\navee\Documents\pytho\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %% [markdown]
# ### The Elbow Method

# %%
plt.plot(range(1,11),wcss)
plt.xticks(np.arange(1,11,step=1))
plt.xlabel('Number of cluster')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# How many clusters are there?
