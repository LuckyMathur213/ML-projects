# %% [markdown]
# # Building a Logistic Regression

# %% [markdown]
# Create a logistic regression based on the bank data provided.
#
# The data is based on the marketing campaign efforts of a Portuguese banking institution. The classification goal is to predict if the client will subscribe a term deposit (variable y).
#
# Note that the first column of the dataset is the index.
#
# Source: [Moro et al., 2014] S. Moro, P. Cortez and P. Rita. A Data-Driven Approach to Predict the Success of Bank Telemarketing. Decision Support Systems, Elsevier, 62:22-31, June 2014

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set()

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load the ‘Example_bank_data.csv’ dataset.

# %%
data=pd.read_csv('Example_bank_data.csv')

# %%
data
# Out:
#      Unnamed: 0  duration    y
# 0             0       117   no
# 1             1       274  yes
# 2             2       167   no
# 3             3       686  yes
# 4             4       157   no
# ..          ...       ...  ...
# 513         513       204   no
# 514         514       806  yes
# 515         515       290   no
# 516         516       473  yes
# 517         517       142   no
#
# [518 rows x 3 columns]

# %% [markdown]
# We want to know whether the bank marketing strategy was successful, so we need to transform the outcome variable into 0s and 1s in order to perform a logistic regression.

# %%
data1=data.copy()

# %%
data = data.drop(['Unnamed: 0'], axis = 1)
data['y'] = data['y'].map({'yes':1, 'no':0})

# %%
data.describe()
# Out:
#           duration           y
# count   518.000000  518.000000
# mean    382.177606    0.500000
# std     344.295990    0.500483
# min       9.000000    0.000000
# 25%     155.000000    0.000000
# 50%     266.500000    0.500000
# 75%     482.750000    1.000000
# max    2653.000000    1.000000

# %% [markdown]
# ### Declare the dependent and independent variables

# %%
y=data['y']
x1=data['duration']

# %% [markdown]
# ### Simple Logistic Regression

# %% [markdown]
# Run the regression and visualize it on a scatter plot (no need to plot the line).

# %%
x=sm.add_constant(x1)
log_reg=sm.Logit(y,x)
results=log_reg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.546118
#          Iterations 7

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  518
# Model:                          Logit   Df Residuals:                      516
# Method:                           MLE   Df Model:                            1
# Date:                Mon, 06 Jan 2025   Pseudo R-squ.:                  0.2121
# Time:                        14:03:58   Log-Likelihood:                -282.89
# converged:                       True   LL-Null:                       -359.05
# Covariance Type:            nonrobust   LLR p-value:                 5.387e-35
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.7001      0.192     -8.863      0.000      -2.076      -1.324
# duration       0.0051      0.001      9.159      0.000       0.004       0.006
# ==============================================================================
# """

# %%
def f(x,b0,b1):
    return np.array(np.exp(b0+x*b1) / (1 + np.exp(b0+x*b1)))

f_sorted = np.sort(f(x1,results.params[0],results.params[1]))
x_sorted = np.sort(np.array(x1))

plt.scatter(x1,y,color='C0')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('Admitted', fontsize = 20)
plt.plot(x_sorted,f_sorted,color='C8')
plt.show()
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_564\966725673.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   f_sorted = np.sort(f(x1,results.params[0],results.params[1]))

# %%
np.set_printoptions(formatter={'float':lambda x:"{0:0.2f}".format(x)})
results.predict()
# Out:
# array([0.25, 0.43, 0.30, 0.86, 0.29, 0.26, 0.22, 0.17, 0.87, 0.32, 0.55,
#        0.23, 0.30, 0.39, 0.35, 0.49, 0.29, 0.25, 0.51, 0.83, 0.84, 0.59,
#        0.66, 0.31, 0.24, 0.25, 0.24, 0.21, 0.35, 0.49, 0.26, 1.00, 0.16,
#        0.99, 0.93, 0.99, 0.34, 0.20, 0.34, 0.86, 0.37, 0.85, 0.66, 0.67,
#        0.27, 0.99, 0.51, 0.18, 0.36, 0.77, 1.00, 0.36, 0.27, 0.55, 0.78,
#        0.20, 0.69, 0.79, 0.32, 0.61, 0.30, 0.16, 0.23, 0.33, 0.25, 0.33,
#        0.28, 0.61, 0.97, 0.39, 0.45, 0.58, 0.29, 1.00, 0.98, 0.44, 0.61,
#        0.59, 0.28, 0.36, 0.24, 0.92, 0.39, 0.48, 0.38, 0.32, 0.84, 0.37,
#        0.31, 0.50, 0.21, 0.28, 0.59, 0.28, 0.20, 0.64, 0.35, 0.98, 0.38,
#        0.41, 0.37, 0.56, 0.78, 0.51, 0.26, 0.55, 0.87, 0.22, 0.29, 0.53,
#        0.98, 0.51, 0.95, 0.59, 0.78, 0.72, 0.65, 0.40, 0.41, 0.68, 0.18,
#        0.73, 0.41, 0.73, 0.44, 0.56, 0.37, 0.52, 0.39, 0.60, 0.31, 0.51,
#        0.90, 0.87, 0.26, 0.57, 0.59, 0.42, 0.39, 0.27, 0.48, 0.44, 0.95,
#        0.24, 0.28, 0.37, 0.20, 0.84, 0.54, 0.41, 0.64, 0.84, 0.25, 0.83,
#        0.79, 0.27, 0.93, 0.24, 0.28, 0.97, 0.74, 0.29, 0.34, 0.30, 0.73,
#        0.54, 0.28, 0.30, 0.27, 0.24, 1.00, 0.39, 0.33, 0.68, 0.68, 0.40,
#        0.98, 0.66, 0.35, 0.33, 0.58, 0.36, 0.86, 0.19, 0.53, 0.46, 0.18,
#        0.98, 0.86, 0.82, 0.87, 0.80, 0.40, 0.24, 0.88, 0.81, 0.59, 0.21,
#        0.26, 0.32, 0.31, 0.49, 0.24, 0.67, 0.21, 0.27, 0.25, 0.30, 0.70,
#        0.54, 0.16, 0.91, 0.43, 0.68, 0.68, 0.37, 0.34, 0.92, 0.45, 0.67,
#        0.27])

# %%
np.array(data['duration'])
# Out:
# array([ 117,  274,  167,  686,  157,  126,   84,   17,  704,  185,  374,
#          91,  169,  249,  215,  324,  159,  120,  337,  640,  663,  403,
#         300,  255,  293,   68,  266,  272,  398,  126,   35,  126,  683,
#         280,  161,  191, 1135,   81, 1447,  436,  132,  328,  175,  145,
#         155,  115,   57,  170,  172,  310,  711,   63,   87,  154,  124,
#         328,  147,   64,  739,  360,  105,  113,  767,  254,  341,  301,
#         148,  171,  712,  104,   39,  229,  311,  238,  364,  133,  261,
#         389,  160,   70,  206,  281,  166,  299,  258, 1011,  169,  355,
#         254,   96,  217,   85,  232,  184,  571,  621,  600,   59, 1130,
#         171,  840,  206,  747,  263,  331,  334,  268,  208,  268,  346,
#         363,  113,  173,   68,  539,   35,  119,  728,  412,  314,   99,
#          25,  252, 1348,  314,  955,  224,  406,  205,  266,  153,  195,
#         316,  768,  300,  483,  391,  276,  275,  175,  126,  101,  653,
#         286,  650,  450,  239,  125, 1855,  128,  951,  545, 1019,  689,
#          58,  156,  626,  984,  632, 1068,  309,  384,  846,  264,  173,
#         288,  154,  151,   88,  394,  474,  330,  292,  141,  154, 1150,
#         194,  113,  423,  222,  345,  141,  275,  809,  132,  207,   16,
#          98, 1806,  175,  193,  374,   86,  460,  207,   11,  496,   80,
#         483,  269,  149,  617,  323,  815,  126,  267,  320,  697,  274,
#        1062,  209,  259,  854,  256,   82,  693,  738,   63,  207,   51,
#         406,  546,   64,  158,  742,  211,  633,  179, 1340,  980,  454,
#         212,  361,  873,  629, 1148,  229,  202,  342,  383,  151,  568,
#          97,   69, 1013, 1357,  417,  102,  873,  525,  180,  609,   72,
#          73,  151,  458,  238,   82,  363,  396,  463,  634, 1422,  251,
#         163,  135,  345,  144,  525,  388,  760,  360,  549,  107, 1311,
#         294,  544,  143,  273,  201,  762,  143,  886, 2301,  252,  958,
#          76, 1234,  265,  204,  157,  250,  456,  114,  308,  154,  185,
#          73,   73,  604,  314,  196,  184,  257,  188,  146,  216, 1152,
#         553,  174,  159,  183,   49,  249,  941,  181,  988,  353,  569,
#         461,  178,  109,  113,  111,   73,  213,  322,  130, 1424,    9,
#        1276,  854, 1319,  203,   56,  199,  690,  230,  673,  458,  475,
#         135, 1176,  344,   40,  219,  565, 2653,  218,  141,  375,  578,
#          58,  491,  592,  188,  424,  163,   11,   95,  191,  116,  198,
#         149,  424, 1009,  247,  295,  393,  155, 1602, 1138,  285,  418,
#         403,  152,  224,  109,  805,  244,  314,  233,  183,  662,  232,
#         180,  336,   74,  148,  405,  143,   59,  449,  211, 1091,  239,
#         262,  228,  379,  585,  338,  123,  374,  712,   83,  159,  357,
#        1087,  340,  898,  401,  582,  519,  455,  257,  258,  482,   42,
#         531,  259,  530,  289,  383,  227,  346,  248,  408,  179,  344,
#         771,  698,  129,  387,  404,  270,  241,  135,  317,  286,  895,
#         109,  151,  230,   57,  655,  367,  260,  446,  653,  113,  645,
#         587,  142,  829,  102,  148, 1019,  537,  160,  204,  164,  523,
#         362,  151,  167,  136,  102, 1980,  243,  192,  482,  477,  252,
#        1127,  459,  211,  193,  395,  223,  686,   51,  355,  298,   42,
#        1143,  688,  628,  706,  608,  250,  107,  716,  619,  406,   73,
#         127,  187,  180,  326,  109,  470,   73,  141,  115,  171,  498,
#         365,   10,  796,  279,  476,  479,  225,  204,  806,  290,  473,
#         142], dtype=int64)

# %%
results.pred_table()
# Out:
# array([[204.00, 55.00],
#        [104.00, 155.00]])

# %%
cm_df=pd.DataFrame(results.pred_table())
cm_df.columns=['Predicted 0','Predicted 1']
cm_df=cm_df.rename(index={0:'Actual 0',1:'Actual 1'})
cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0        204.0         55.0
# Actual 1        104.0        155.0

# %%
accuracy=((204+155)/(204+55+104+155))*100

# %%
accuracy
# Out:
# 69.3050193050193

# %%
cm=np.array(cm_df)
accuracy_train=(cm[0,0]+cm[1,1])/cm.sum()
accuracy_train
# Out:
# 0.693050193050193
