# %%
#The simplest,, most flexible way to work with scalers, vectors, matrices is by using arrays
#numpy is optimized for such operations
import numpy as np

# %%
#Scalers
s=5

# %%
s
# Out:
# 5

# %%
#Vectors
#By default, v is a row vector
v=np.array([5,-2,4])
v
# Out:
# array([ 5, -2,  4])

# %%
#Matrix. This matrix can be seen as containing 2 vectors
m=np.array([[5,12,6],[-3,0,14]])
m
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
#type(x) returns data type of x var
type(s)
# Out:
# int

# %%
type(v)
# Out:
# numpy.ndarray

# %%
type(m)
# Out:
# numpy.ndarray

# %%
#ndarray stands for n dimentional array
#v is a 1D array, m is a 2D array

# %%
#to convert integer into a array
s_array=np.array(5)
s_array
# Out:
# array(5)

# %%
type(s_array)
# Out:
# numpy.ndarray

# %%
#shape returns shape (dimensions) of a var
m.shape
# Out:
# (2, 3)

# %%
v.shape
# Out:
# (3,)

# %%
#reshape gives an array a new shape w/o changing its data. It can be used to create a row or a column vector
#x.reshape(desired form). There are 2 possibilities-(a) 1,3- gives row vector (2) 3, 1- gives column vector
v.reshape(1,3)
# Out:
# array([[ 5, -2,  4]])

# %%
v.reshape(3,1)
# Out:
# array([[ 5],
#        [-2],
#        [ 4]])

# %%
#int objects don't have shape
s.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[106], line 2
#       1 #int objects don't have shape
# ----> 2 s.shape
#
# AttributeError: 'int' object has no attribute 'shape'

# %%
#it's empty as a scaler is a zero D object
s_array.shape
# Out:
# ()

# %%
# adding and substracting matrices
m2=np.array([[3,6,2],[52,6,2]])
m2
# Out:
# array([[ 3,  6,  2],
#        [52,  6,  2]])

# %%
m+m2
# Out:
# array([[ 8, 18,  8],
#        [49,  6, 16]])

# %%
m-m2
# Out:
# array([[  2,   6,   4],
#        [-55,  -6,  12]])

# %%
# adding and substracting vectors
v1=np.array([7,9,1])

# %%
v+v1
# Out:
# array([12,  7,  5])

# %%
v-v1
# Out:
# array([ -2, -11,   3])

# %%
#adding and substracting scalers
5+5, 5-1
# Out:
# (10, 4)

# %%
#exceptions (addition with scaler) can work in python
m
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
m+1
# Out:
# array([[ 6, 13,  7],
#        [-2,  1, 15]])

# %%
v+1
# Out:
# array([ 6, -1,  5])

# %%
m+np.array([1])
# Out:
# array([[ 6, 13,  7],
#        [-2,  1, 15]])

# %%
v+np.array([1])
# Out:
# array([ 6, -1,  5])

# %%
#Transposing matrices
A=np.array([[5,12,6],[-3,0,14]])
A
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
#array.T returns transpose of an array
A.T
# Out:
# array([[ 5, -3],
#        [12,  0],
#        [ 6, 14]])

# %%
B=np.array([[5,3],[-2,1]])
B
# Out:
# array([[ 5,  3],
#        [-2,  1]])

# %%
B.T
# Out:
# array([[ 5, -2],
#        [ 3,  1]])

# %%
C=np.array([[5,12],[7,6],[-3,0],[23,14]])
C
# Out:
# array([[ 5, 12],
#        [ 7,  6],
#        [-3,  0],
#        [23, 14]])

# %%
C.T
# Out:
# array([[ 5,  7, -3, 23],
#        [12,  6,  0, 14]])

# %%
#Any scaler transposed = itself
s=np.array([5])
s
# Out:
# array([5])

# %%
s.T
# Out:
# array([5])

# %%
#transposing vector=vector because in python 1D arrays don't get transposed
v.T
# Out:
# array([ 5, -2,  4])

# %%
#to transpose a vector, reshape it into a 3 by 1 or a 2D array
v_reshaped=v.reshape(1,3)
v_reshaped
# Out:
# array([[ 5, -2,  4]])

# %%
v_reshaped.T
# Out:
# array([[ 5],
#        [-2],
#        [ 4]])

# %%
#np.dot() returns 2 objects' dot product
x=np.array([2,8,-4])
y=np.array([1,-7,3])
np.dot(x,y)
# Out:
# -66

# %%
# scalar * scalar
np.dot(5,6)
# Out:
# 30

# %%
#scalar * vector
5*x
# Out:
# array([ 10,  40, -20])

# %%
#scalar * matrix
5*C
# Out:
# array([[ 25,  60],
#        [ 35,  30],
#        [-15,   0],
#        [115,  70]])

# %%
#matrix * matrix requires np.dot(x,y) method
m3=np.array([[3,5,8,4],[11,9,6,10],[12,13,2,7]])
m3
# Out:
# array([[ 3,  5,  8,  4],
#        [11,  9,  6, 10],
#        [12, 13,  2,  7]])

# %%
m
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
np.dot(m,m3)
# Out:
# array([[219, 211, 124, 182],
#        [159, 167,   4,  86]])

# %%
m4=np.array([[-12,5,-5,1,6],[6,-2,0,0,-3],[10,2,0,8,0],[9,-4,8,3,-6]])
m4
# Out:
# array([[-12,   5,  -5,   1,   6],
#        [  6,  -2,   0,   0,  -3],
#        [ 10,   2,   0,   8,   0],
#        [  9,  -4,   8,   3,  -6]])

# %%
m5=np.array([[6,-1],[8,-4],[2,-2],[7,4],[-6,-9]])
m5
# Out:
# array([[ 6, -1],
#        [ 8, -4],
#        [ 2, -2],
#        [ 7,  4],
#        [-6, -9]])

# %%
np.dot(m4,m5)
# Out:
# array([[-71, -48],
#        [ 38,  29],
#        [132,  14],
#        [ 95,  57]])
