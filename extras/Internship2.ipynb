# %%
thisset={"apple","banana","cherry"}
print(type(thisset))
# Out:
# <class 'set'>

# %%
cars=("a","b","c")
for i in cars:
    print(cars)
# Out:
# ('a', 'b', 'c')
# ('a', 'b', 'c')
# ('a', 'b', 'c')

# %%
def greet():
    name=input("who am i speaking to ?")
    print("Hello" + name + "!")

greet()
