# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data=pd.read_csv('2.01.+Admittance.csv')

# %%
data
# Out:
#       SAT Admitted
# 0    1363       No
# 1    1792      Yes
# 2    1954      Yes
# 3    1653       No
# 4    1593       No
# ..    ...      ...
# 163  1722      Yes
# 164  1750      Yes
# 165  1555       No
# 166  1524       No
# 167  1461       No
#
# [168 rows x 2 columns]

# %%
# OG dataset shouldn't be changed, so a copy should be used
data1=data.copy()
data1['Admitted']=data1['Admitted'].map({'Yes':1,'No':0})
data1
# Out:
#       SAT  Admitted
# 0    1363         0
# 1    1792         1
# 2    1954         1
# 3    1653         0
# 4    1593         0
# ..    ...       ...
# 163  1722         1
# 164  1750         1
# 165  1555         0
# 166  1524         0
# 167  1461         0
#
# [168 rows x 2 columns]

# %%
y=data1['Admitted']
x1=data1['SAT']

# %%
plt.scatter(x1,y,color='C0')
plt.xlabel('SAT',fontsize=20)
plt.ylabel('Admitted',fontsize=20)
plt.show()

# %%
x = sm.add_constant(x1)
reg_lin = sm.OLS(y,x)
results_lin = reg_lin.fit()
plt.scatter(x1,y,color = 'C0')
y_hat = x1*results_lin.params[1]+results_lin.params[0]
plt.plot(x1,y_hat,lw=2.5,color='C8')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('Admitted', fontsize = 20)
plt.show()
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_2700\3487026854.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_hat = x1*results_lin.params[1]+results_lin.params[0]

# %%
#Above reg doesn't fit the data, it's not suitable for the data and analysis
